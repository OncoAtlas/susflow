# %% [markdown]
# # susflow — testes por sistema

# %%
from susflow.systems import sinasc, sim, sinan, cnes, siasus, sihsus

# %% [markdown]
# ## SINASC — Nascidos Vivos

# %%
sinasc.listar(uf="PB")
# Out:
# ['DNPB1996.DBC',
#  'DNPB1997.DBC',
#  'DNPB1998.DBC',
#  'DNPB1999.DBC',
#  'DNPB2000.DBC',
#  'DNPB2001.DBC',
#  'DNPB2002.DBC',
#  'DNPB2003.DBC',
#  'DNPB2004.DBC',
#  'DNPB2005.dbc',
#  'DNPB2006.DBC',
#  'DNPB2007.dbc',
#  'DNPB2008.dbc',
#  'DNPB2009.dbc',
#  'DNPB2010.DBC',
#  'DNPB2011.DBC',
#  'DNPB2012.DBC',
#  'DNPB2013.dbc',
#  'DNPB2014.dbc',
#  'DNPB2015.dbc',
#  'DNPB2016.dbc',
#  'DNPB2017.dbc',
#  'DNPB2018.dbc',
#  'DNPB2019.dbc',
#  'DNPB2020.dbc',
#  'DNPB2021.dbc',
#  'DNPB2022.dbc']

# %%
df = sinasc.ler(uf="PB", ano=2022)
print(df.shape)
df.head(3)
# Out:
# (50892, 61)
#   ORIGEM CODESTAB CODMUNNASC LOCNASC IDADEMAE ESTCIVMAE ESCMAE CODOCUPMAE  \
# 0      1  2514729     230170       1       22         1      4     612005
# 1      1  2564211     230190       1       31         2      5     223505
# 2      1  2564211     230190       1       35         2      5     413225
#
#   QTDFILVIVO QTDFILMORT  ... TPDOCRESP DTDECLARAC ESCMAEAGR1 STDNEPIDEM  \
# 0         02         00  ...         3   21032022         04          0
# 1         00         01  ...         4   17012022         08          0
# 2         01         00  ...         4   17012022         08          0
#
#   STDNNOVA CODPAISRES TPROBSON PARIDADE KOTELCHUCK CONTADOR
# 0        1          1       05        1          5   219758
# 1        1          1       10        1          5   219997
# 2        1          1       05        1          3   220001
#
# [3 rows x 61 columns]

# %% [markdown]
# ## SIM — Mortalidade por UF

# %%
sim.listar(uf="PB")
# Out:
# ['DOPB1996.dbc',
#  'DOPB1997.dbc',
#  'DOPB1998.dbc',
#  'DOPB1999.dbc',
#  'DOPB2000.dbc',
#  'DOPB2001.dbc',
#  'DOPB2002.dbc',
#  'DOPB2003.dbc',
#  'DOPB2004.dbc',
#  'DOPB2005.dbc',
#  'DOPB2006.dbc',
#  'DOPB2007.DBC',
#  'DOPB2008.dbc',
#  'DOPB2009.dbc',
#  'DOPB2010.DBC',
#  'DOPB2011.DBC',
#  'DOPB2012.DBC',
#  'DOPB2013.dbc',
#  'DOPB2014.dbc',
#  'DOPB2015.dbc',
#  'DOPB2016.dbc',
#  'DOPB2017.dbc',
#  'DOPB2018.dbc',
#  'DOPB2019.dbc',
#  'DOPB2020.dbc',
#  'DOPB2021.dbc',
#  'DOPB2022.dbc',
#  'DOPB2023.dbc',
#  'DOPB2024.dbc']

# %%
df = sim.ler(uf="PB", ano=2022)
print(df.shape)
df.head(3)
# Out:
# (32405, 87)
#   ORIGEM TIPOBITO   DTOBITO HORAOBITO NATURAL CODMUNNATU    DTNASC IDADE SEXO  \
# 0      1        2  02022022      0420     825     250240  25021940   481    2
# 1      1        2  04052022      1300     825     250080  15021958   464    1
# 2      1        2  08052022      1800     825     250080  15061940   481    1
#
#   RACACOR  ... FONTES TPRESGINFO TPNIVELINV NUDIASINF DTCADINF MORTEPARTO  \
# 0       4  ...
# 1       4  ...
# 2       4  ...
#
#   DTCONCASO FONTESINF ALTCAUSA CONTADOR
# 0                                   224
# 1                                   551
# 2                                   925
#
# [3 rows x 87 columns]

# %% [markdown]
# ## SIM — Especial (EXT / FET / INF / MAT)

# %%
sim.listar_especial(tipo="EXT")
# Out:
# ['DOEXT00.DBC',
#  'DOEXT01.DBC',
#  'DOEXT02.DBC',
#  'DOEXT03.DBC',
#  'DOEXT04.DBC',
#  'DOEXT05.DBC',
#  'DOEXT06.DBC',
#  'DOEXT07.DBC',
#  'DOEXT08.DBC',
#  'DOEXT09.DBC',
#  'DOEXT10.DBC',
#  'DOEXT11.DBC',
#  'DOEXT12.DBC',
#  'DOEXT13.dbc',
#  'DOEXT14.dbc',
#  'DOEXT15.dbc',
#  'DOEXT16.dbc',
#  'DOEXT17.dbc',
#  'DOEXT18.dbc',
#  'DOEXT19.dbc',
#  'DOEXT20.dbc',
#  'DOEXT21.dbc',
#  'DOEXT22.dbc',
#  'DOEXT23.dbc',
#  'DOEXT24.dbc',
#  'DOEXT96.DBC',
#  'DOEXT97.DBC',
#  'DOEXT98.DBC',
#  'DOEXT99.DBC']

# %%
df = sim.ler_especial(tipo="EXT", ano=2022)
print(df.shape)
df.head(3)
# Out:
# (152945, 87)
#   ORIGEM TIPOBITO   DTOBITO HORAOBITO NATURAL CODMUNNATU    DTNASC IDADE SEXO  \
# 0      1        2  30032022      1840     850     500345  03011967   455    1
# 1      1        2  06032022      0400     841     412760  28101994   427    1
# 2      1        2  05052022      2233     833     330490  21082011   410    2
#
#   RACACOR  ... FONTES TPRESGINFO TPNIVELINV NUDIASINF DTCADINF MORTEPARTO  \
# 0       1  ...
# 1       1  ...
# 2       1  ...
#
#   DTCONCASO FONTESINF ALTCAUSA CONTADOR
# 0                                    15
# 1                                    35
# 2                                   100
#
# [3 rows x 87 columns]

# %% [markdown]
# ## SINAN — Agravos de Notificação

# %%
sinan.doencas()
# Out:
# {'ACBI': 'Acidente por animal peçonhento',
#  'ACGR': 'Acidente de trabalho grave',
#  'ANIM': 'Acidente por animal (outros)',
#  'ANTR': 'Antraz (Carbúnculo)',
#  'BOTU': 'Botulismo',
#  'CANC': 'Câncer relacionado ao trabalho',
#  'CHAG': 'Doença de Chagas',
#  'CHIK': 'Chikungunya',
#  'COLE': 'Cólera',
#  'COQU': 'Coqueluche',
#  'DCRJ': 'Doença de Creutzfeldt-Jakob',
#  'DENG': 'Dengue',
#  'DERM': 'Dermatose ocupacional',
#  'DIFT': 'Difteria',
#  'ESPO': 'Esporotricose',
#  'ESQU': 'Esquistossomose',
#  'FMAC': 'Febre maculosa',
#  'FTIF': 'Febre tifoide',
#  'HANS': 'Hanseníase',
#  'HANT': 'Hantavirose',
#  'IEXO': 'Intoxicação exógena',
#  'LEIV': 'Leishmaniose visceral',
#  'LEPT': 'Leptospirose',
#  'LERD': 'LER/DORT',
#  'LTA': 'Leishmaniose tegumentar americana',
#  'MALA': 'Malária',
#  'MENI': 'Meningite',
#  'MENT': 'Transtorno mental relacionado ao trabalho',
#  'NTRA': 'Noma (Cancrum oris)',
#  'PAIR': 'Perda auditiva induzida por ruído',
#  'PEST': 'Peste',
# ...

# %%
sinan.listar(doenca="DENG")
# Out:
# ['DENGBR00.dbc',
#  'DENGBR01.dbc',
#  'DENGBR02.dbc',
#  'DENGBR03.dbc',
#  'DENGBR04.dbc',
#  'DENGBR05.dbc',
#  'DENGBR06.dbc',
#  'DENGBR07.dbc',
#  'DENGBR08.dbc',
#  'DENGBR09.dbc',
#  'DENGBR10.dbc',
#  'DENGBR11.dbc',
#  'DENGBR12.dbc',
#  'DENGBR13.dbc',
#  'DENGBR14.dbc',
#  'DENGBR15.dbc',
#  'DENGBR16.dbc',
#  'DENGBR17.dbc',
#  'DENGBR18.dbc',
#  'DENGBR19.dbc',
#  'DENGBR20.dbc',
#  'DENGBR21.dbc',
#  'DENGBR22.dbc',
#  'DENGBR23.dbc',
#  'DENGBR24.dbc']

# %%
df = sinan.ler(doenca="DENG", ano=2022)
print(df.shape)
df.head(3)

# %% [markdown]
# ## SIHSUS — Internações Hospitalares

# %%
sihsus.prefixos()

# %%
sihsus.listar(uf="PB", prefixo="RD")

# %%
df = sihsus.ler(uf="PB", ano=2022, mes=1)
print(df.shape)
df.head(3)

# %% [markdown]
# ## SIASUS — Produção Ambulatorial

# %%
siasus.prefixos()

# %%
siasus.listar(uf="PB", prefixo="PA")

# %%
df = siasus.ler(uf="PB", ano=2022, mes=1)
print(df.shape)
df.head(3)

# %% [markdown]
# ## CNES — Estabelecimentos de Saúde

# %%
cnes.subtipos()

# %%
cnes.listar(uf="PB", tipo="ST")

# %%
df = cnes.ler(uf="PB", ano=2022, mes=1, tipo="ST")
print(df.shape)
df.head(3)
