# %%
from susflow.systems import sinasc, sim, sinan
import pandas as pd

df = sinasc.ler(uf="PB", ano=1996)

# %%
# visão geral
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50115 entries, 0 to 50114
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CONTADOR    50115 non-null  str
#  1   LOCNASC     50115 non-null  str
#  2   CODMUNNASC  50115 non-null  str
#  3   IDADEMAE    50115 non-null  str
#  4   ESTCIVMAE   50115 non-null  str
#  5   ESCMAE      50115 non-null  str
#  6   CODOCUPMAE  50115 non-null  str
#  7   QTDFILVIVO  50115 non-null  str
#  8   QTDFILMORT  50115 non-null  str
#  9   CODMUNRES   50115 non-null  str
#  10  GESTACAO    50115 non-null  str
#  11  GRAVIDEZ    50115 non-null  str
#  12  PARTO       50115 non-null  str
#  13  CONSULTAS   50115 non-null  str
#  14  DTNASC      50115 non-null  str
#  15  SEXO        50115 non-null  str
#  16  APGAR1      50115 non-null  str
#  17  APGAR5      50115 non-null  str
#  18  RACACOR     50115 non-null  str
#  19  PESO        50115 non-null  str
# ...

# %%
df.describe(include="all")
# Out:
#        CONTADOR LOCNASC CODMUNNASC IDADEMAE ESTCIVMAE ESCMAE CODOCUPMAE  \
# count     50115   50115      50115    50115     50115  50115      50115
# unique    50115       6        194       44         1     10          1
# top           1       1    2507507       99                6
# freq          1   49432      17728     3982     50115  14910      50115
#
#        QTDFILVIVO QTDFILMORT CODMUNRES  ... GRAVIDEZ  PARTO CONSULTAS  \
# count       50115      50115     50115  ...    50115  50115     50115
# unique         24         15       169  ...        6      3         7
# top                            2507507  ...        1      1         4
# freq        23751      42386     11585  ...    46072  29672     14977
#
#           DTNASC   SEXO APGAR1 APGAR5 RACACOR   PESO CODANOMAL
# count      50115  50115  50115  50115   50115  50115     50115
# unique       367      4     12     15       6    682         1
# top     01011996      1     08     10           3000
# ...

# %%
# distribuição de peso ao nascer
pd.to_numeric(df["PESO"], errors="coerce").hist(bins=40)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 # distribuição de peso ao nascer
# ----> 2 pd.to_numeric(df["PESO"], errors="coerce").hist(bins=40)
#
# File ~/prog/facul/susflow/.venv/lib/python3.13/site-packages/pandas/plotting/_core.py:131, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      49 @set_module("pandas.plotting")
#      50 def hist_series(
#      51     self: Series,
#    (...)     63     **kwargs,
#      64 ):
#      65     """
#      66     Draw histogram of the input series using matplotlib.
#      67
#    (...)    129         >>> hist = ser.groupby(level=0).hist()
#     130     """
# --> 131     plot_backend = _get_plot_backend(backend)
#     132     return plot_backend.hist_series(
#     133         self,
#     134         by=by,
# ...

# %%
# nascimentos por sexo
df["SEXO"].value_counts()
# Out:
# SEXO
# 1    25698
# 2    24298
# 0      118
# 9        1
# Name: count, dtype: int64
